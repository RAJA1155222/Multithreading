# %% [markdown]
# Q1. What is multithreading in Python? Why is it used? Name the module used to handle threads in Python.
#
# Multithreading is a technique in which multiple threads run concurrently within a single program.
#
# A thread is the smallest unit of execution inside a process.
#
# Why multithreading is used
#
# To perform multiple tasks at the same time
#
# To improve responsiveness of programs
#
# To efficiently handle I/O-bound tasks (file, network, etc.)

# %% [markdown]
# Q2. Why is the threading module used? Write the use of the following functions
#
# The threading module is used to:
#
# create threads
#
# manage threads
#
# synchronize thread execution
#
# (a) activeCount()
#
# Returns the number of thread objects that are currently alive.
#
# threading.activeCount()
# (b) currentThread()
#
# Returns the currently executing thread object.
#
# threading.currentThread()
# (c) enumerate()
#
# Returns a list of all currently active thread objects.
#
# threading.enumerate()

# %% [markdown]
# Q3. Explain the following functions
# (a) run()
#
# It contains the code that a thread executes.
#
# It is automatically called when a thread starts.
#
# (b) start()
#
# Starts the execution of a thread and internally calls the run() method.
#
# (c) join()
#
# Makes the calling thread wait until the thread finishes its execution.
#
# (d) isAlive()
#
# Checks whether a thread is still running.
#
# Returns:
#
# True → if thread is alive
#
# False → if thread has finished

# %% [markdown]
# Q4. Write a Python program to create two threads.
#
# Thread one prints squares and thread two prints cubes.**

# %%
import threading

def print_squares():
    squares = []
    for i in range(1, 6):
        squares.append(i * i)
    print("Squares:", squares)

def print_cubes():
    cubes = []
    for i in range(1, 6):
        cubes.append(i * i * i)
    print("Cubes:", cubes)

t1 = threading.Thread(target=print_squares)
t2 = threading.Thread(target=print_cubes)

t1.start()
t2.start()

t1.join()
t2.join()

# %% [markdown]
# Q5. State advantages and disadvantages of multithreading
# ✅ Advantages
#
# Better CPU utilization
#
# Faster execution for I/O-bound tasks
#
# Improved program responsiveness
#
# Efficient handling of multiple tasks
#
# ❌ Disadvantages
#
# Difficult to debug
#
# Risk of deadlocks and race conditions
#
# More complex program design
#
# Overhead of managing threads
#
# Q6. Explain deadlocks and race conditions
# 🔴 Deadlock
#
# A deadlock occurs when two or more threads wait for each other to release resources, and none of them can continue.
#
# Example idea:
#
# Thread A holds resource X and waits for Y
#
# Thread B holds resource Y and waits for X
#
# Result → both threads stop forever.
